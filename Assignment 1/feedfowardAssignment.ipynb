# %% [markdown]
# # Deep versus wide networks
# ### Question 1

# %%
import math
import random

import numpy as np
import wandb
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# For reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

device = torch.device("cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
class NoisyXORDataset(Dataset):
    """
    Dataset for the noisy XOR problem.

    Each sample is generated as:
        (x1, x2, y) = (m1 + s * eta1, m2 + s * eta2, m1 xor m2)
    where m1, m2 ∈ {0,1}, eta1, eta2 ~ N(0, 1).
    """
    def __init__(self, n_samples=1000, s=0.1, seed=None):
        super().__init__()
        if seed is not None:
            g = torch.Generator()
            g.manual_seed(seed)
        else:
            g = None

        # Sample cluster centers m1, m2 ∈ {0, 1}
        m = torch.randint(0, 2, (n_samples, 2), generator=g, dtype=torch.float32)  # shape (N,2)
        m1 = m[:, 0]
        m2 = m[:, 1]

        # Gaussian noise
        eta = torch.randn(n_samples, 2, generator=g)

        # Inputs
        x = m + s * eta  # (x1, x2)

        # XOR label
        y = (m1 != m2).float()  # shape (N,)

        self.x = x
        self.y = y

    def __len__(self):
        return self.x.shape[0]

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
def plot_dataset(dataset, title="Dataset", ax=None):
    """
    Scatter plot of (x1, x2) colored by class y (0 or 1).
    """
    x_all = dataset.x.numpy()
    y_all = dataset.y.numpy()

    if ax is None:
        fig, ax = plt.subplots(figsize=(5, 5))

    class0 = x_all[y_all == 0]
    class1 = x_all[y_all == 1]

    ax.scatter(class0[:, 0], class0[:, 1], label="Class 0", alpha=0.7, edgecolor="k")
    ax.scatter(class1[:, 0], class1[:, 1], label="Class 1", alpha=0.7, edgecolor="k")

    ax.set_xlabel("x1")
    ax.set_ylabel("x2")
    ax.set_title(title)
    ax.legend()
    ax.grid(True)

    if ax is None:
        plt.show()

# %%
# Hyperparameters for data
n_train = 2000
n_val = 1000
s = 0.1  # standard deviation of noise

train_dataset = NoisyXORDataset(n_samples=n_train, s=s, seed=seed)
val_dataset = NoisyXORDataset(n_samples=n_val, s=s, seed=seed + 1)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
plot_dataset(train_dataset, title="Training set", ax=axes[0])
plot_dataset(val_dataset, title="Validation set", ax=axes[1])
plt.tight_layout()
plt.show()

# %%
class FeedForwardNet(nn.Module):
    """
    Simple feed-forward neural network for binary classification on 2D input.

    Default: 2 → 3 → 1 with tanh hidden activation and identity output.
    We apply sigmoid in the loss (using BCEWithLogitsLoss).
    """
    def __init__(self, input_dim=2, hidden_sizes=(3,), output_dim=1, activation=nn.Tanh):
        super().__init__()

        layers = []
        in_features = input_dim

        # Hidden layers
        for h in hidden_sizes:
            layers.append(nn.Linear(in_features, h))
            layers.append(activation())
            in_features = h

        # Output layer (identity activation)
        layers.append(nn.Linear(in_features, output_dim))
        # Identity at the end is implicit; BCEWithLogitsLoss expects raw logits

        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)  # logits (no sigmoid here)

# %%
hidden_sizes = (3, 3, 3)
model = FeedForwardNet(input_dim=2, hidden_sizes=hidden_sizes, output_dim=1).to(device)
print(model)
# Out:
# FeedForwardNet(
#   (model): Sequential(
#     (0): Linear(in_features=2, out_features=3, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=3, out_features=3, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=3, out_features=3, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=3, out_features=1, bias=True)
#   )
# )

# %%
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
# Loss and optimizer
criterion = nn.BCEWithLogitsLoss()  # expects logits and float targets in [0,1]
learning_rate = 1e-2
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, n_epochs=100):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(1, n_epochs + 1):
        # ---- Training ----
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for x_batch, y_batch in train_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            logits = model(x_batch).squeeze(1)  # (batch,)
            loss = criterion(logits, y_batch)

            loss.backward()
            optimizer.step()

            running_loss += loss.item() * x_batch.size(0)

            # Accuracy
            with torch.no_grad():
                probs = torch.sigmoid(logits)
                preds = (probs >= 0.5).float()
                correct += (preds == y_batch).sum().item()
                total += y_batch.size(0)

        epoch_train_loss = running_loss / total
        epoch_train_acc = correct / total

        # ---- Validation ----
        model.eval()
        val_running_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for x_batch, y_batch in val_loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)

                logits = model(x_batch).squeeze(1)
                loss = criterion(logits, y_batch)

                val_running_loss += loss.item() * x_batch.size(0)

                probs = torch.sigmoid(logits)
                preds = (probs >= 0.5).float()
                val_correct += (preds == y_batch).sum().item()
                val_total += y_batch.size(0)

        epoch_val_loss = val_running_loss / val_total
        epoch_val_acc = val_correct / val_total

        wandb.log(
            {
                "epoch": epoch,
                "train_loss": epoch_train_loss,
                "val_loss": epoch_val_loss,
                "train_acc": epoch_train_acc,
                "val_acc": epoch_val_acc,
            }
        )

        train_losses.append(epoch_train_loss)
        val_losses.append(epoch_val_loss)
        train_accuracies.append(epoch_train_acc)
        val_accuracies.append(epoch_val_acc)

        if epoch % 10 == 0 or epoch == 1:
            print(
                f"Epoch {epoch:3d}/{n_epochs} | "
                f"Train loss: {epoch_train_loss:.4f}, acc: {epoch_train_acc:.3f} | "
                f"Val loss: {epoch_val_loss:.4f}, acc: {epoch_val_acc:.3f}"
            )

    history = {
        "train_loss": train_losses,
        "val_loss": val_losses,
        "train_acc": train_accuracies,
        "val_acc": val_accuracies,
    }
    return history

# %%
n_epochs = 100

wandb.init(
    project="dl-assignment1-xor",
    name="xor_depth3_width3",
    config={
        "model": "FeedForwardNet",
        "depth": 3,
        "width": 3,
        "n_train": n_train,
        "n_val": n_val,
        "batch_size": batch_size,
        "learning_rate": learning_rate,
        "n_epochs": n_epochs,
        "noise_std": s,
    },
)

wandb.watch(model, log="all", log_freq=10)
history = train_model(model, train_loader, val_loader, criterion, optimizer, n_epochs=n_epochs)
wandb.finish()
# Out:
# wandb: Currently logged in as: last24ag (last24ag-copenhagen-business-school) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_182542-gtnjrrdc</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/gtnjrrdc' target="_blank">xor_depth3_width3</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/gtnjrrdc' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/gtnjrrdc</a>
# Epoch   1/100 | Train loss: 0.6912, acc: 0.569 | Val loss: 0.6756, acc: 0.550
# Epoch  10/100 | Train loss: 0.3553, acc: 0.682 | Val loss: 0.3646, acc: 0.743
# Epoch  20/100 | Train loss: 0.0100, acc: 1.000 | Val loss: 0.0091, acc: 1.000
# Epoch  30/100 | Train loss: 0.0016, acc: 1.000 | Val loss: 0.0016, acc: 1.000
# Epoch  40/100 | Train loss: 0.0009, acc: 1.000 | Val loss: 0.0009, acc: 1.000
# Epoch  50/100 | Train loss: 0.0006, acc: 1.000 | Val loss: 0.0006, acc: 1.000
# Epoch  60/100 | Train loss: 0.0005, acc: 1.000 | Val loss: 0.0005, acc: 1.000
# Epoch  70/100 | Train loss: 0.0004, acc: 1.000 | Val loss: 0.0004, acc: 1.000
# Epoch  80/100 | Train loss: 0.0003, acc: 1.000 | Val loss: 0.0003, acc: 1.000
# Epoch  90/100 | Train loss: 0.0002, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# Epoch 100/100 | Train loss: 0.0002, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁▂▁▃████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▇▆▅▅▅▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▄▁▄▄▄▄██████████████████████████████████</td></tr><tr><td>val_loss</td><td>█▇▇▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.00018</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>0.00018</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">xor_depth3_width3</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/gtnjrrdc' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/gtnjrrdc</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_182542-gtnjrrdc/logs</code>

# %%
epochs = np.arange(1, n_epochs + 1)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Loss
axes[0].plot(epochs, history["train_loss"], label="Train loss")
axes[0].plot(epochs, history["val_loss"], label="Val loss")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].set_title("Binary cross entropy loss")
axes[0].legend()
axes[0].grid(True)

# Accuracy
axes[1].plot(epochs, history["train_acc"], label="Train acc")
axes[1].plot(epochs, history["val_acc"], label="Val acc")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].set_title("Accuracy")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question 3.2

# %%
def build_model(depth, width, input_dim=2, output_dim=1):
    """
    Build a feed-forward net with `depth` hidden layers, each of size `width`.
    depth = 0 -> no hidden layers: just Linear(2 -> 1).
    """
    if depth == 0:
        hidden_sizes = ()
    else:
        hidden_sizes = (width,) * depth

    model = FeedForwardNet(
        input_dim=input_dim,
        hidden_sizes=hidden_sizes,
        output_dim=output_dim
    ).to(device)

    return model

# %%
def train_once_and_eval(depth, width,
                        n_train=2000,
                        s=0.1,
                        n_epochs=100,
                        batch_size=64,
                        learning_rate=1e-2,
                        n_eval=2000):
    """
    Train one model with given depth/width and return the loss on a NEW dataset.
    """
    # 1) New training data for this run
    train_dataset = NoisyXORDataset(n_samples=n_train, s=s)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    # 2) Build model, loss, optimizer
    model = build_model(depth=depth, width=width)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # 3) Train (simple loop; no validation here)
    model.train()
    for epoch in range(n_epochs):
        for x_batch, y_batch in train_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            logits = model(x_batch).squeeze(1)
            loss = criterion(logits, y_batch)
            loss.backward()
            optimizer.step()

    # 4) Evaluate on a *new* dataset
    eval_dataset = NoisyXORDataset(n_samples=n_eval, s=s)
    eval_loader = DataLoader(eval_dataset, batch_size=256, shuffle=False)

    model.eval()
    total_loss = 0.0
    total = 0
    with torch.no_grad():
        for x_batch, y_batch in eval_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            logits = model(x_batch).squeeze(1)
            loss = criterion(logits, y_batch)
            total_loss += loss.item() * x_batch.size(0)
            total += x_batch.size(0)

    eval_loss = total_loss / total
    return eval_loss

# %%
import numpy as np
import pandas as pd

depth_values = [0, 1, 2, 3]
width_values = [1, 2, 3]
n_repeats = 5          # you can increase to 10 if you have time/compute
s = 0.1                # same noise level as before
n_train = 2000
n_eval = 2000
n_epochs = 100
batch_size = 64
learning_rate = 1e-2

results = []

for depth in depth_values:
    for width in width_values:
        print(f"\n=== Depth {depth}, Width {width} ===")
        losses = []
        for r in range(n_repeats):
            print(f"  Run {r+1}/{n_repeats} ...", end="")
            eval_loss = train_once_and_eval(
                depth=depth,
                width=width,
                n_train=n_train,
                s=s,
                n_epochs=n_epochs,
                batch_size=batch_size,
                learning_rate=learning_rate,
                n_eval=n_eval,
            )
            losses.append(eval_loss)
            print(f"  eval loss = {eval_loss:.4f}")

        mean_loss = float(np.mean(losses))
        std_loss = float(np.std(losses))

        results.append({
            "depth": depth,
            "width": width,
            "mean_eval_loss": mean_loss,
            "std_eval_loss": std_loss,
        })

df_results = pd.DataFrame(results)
df_results
# Out:
# === Depth 0, Width 1 ===
#   Run 1/5 ...  eval loss = 0.6952
#   Run 2/5 ...  eval loss = 0.6925
#   Run 3/5 ...  eval loss = 0.6946
#   Run 4/5 ...  eval loss = 0.6947
#   Run 5/5 ...  eval loss = 0.6935
#
# === Depth 0, Width 2 ===
#   Run 1/5 ...  eval loss = 0.6934
#   Run 2/5 ...  eval loss = 0.6921
#   Run 3/5 ...  eval loss = 0.6929
#   Run 4/5 ...  eval loss = 0.6926
#   Run 5/5 ...  eval loss = 0.6940
#
# === Depth 0, Width 3 ===
#   Run 1/5 ...  eval loss = 0.6931
#   Run 2/5 ...  eval loss = 0.6945
#   Run 3/5 ...  eval loss = 0.6943
#   Run 4/5 ...  eval loss = 0.6941
#   Run 5/5 ...  eval loss = 0.6932
#
# === Depth 1, Width 1 ===
#   Run 1/5 ...  eval loss = 0.4840
#   Run 2/5 ...  eval loss = 0.4905
#   Run 3/5 ...  eval loss = 0.4784
#   Run 4/5 ...  eval loss = 0.5027
#   Run 5/5 ...  eval loss = 0.4799
#
# === Depth 1, Width 2 ===
#   Run 1/5 ...  eval loss = 0.0033
#   Run 2/5 ...  eval loss = 0.3537
#   Run 3/5 ...  eval loss = 0.0050
#   Run 4/5 ...  eval loss = 0.3373
#   Run 5/5 ...  eval loss = 0.3437
#
# === Depth 1, Width 3 ===
#   Run 1/5 ...  eval loss = 0.0015
#   Run 2/5 ...  eval loss = 0.0017
#   Run 3/5 ...  eval loss = 0.0015
#   Run 4/5 ...  eval loss = 0.0018
#   Run 5/5 ...  eval loss = 0.3475
#
# === Depth 2, Width 1 ===
#   Run 1/5 ...  eval loss = 0.4765
#   Run 2/5 ...  eval loss = 0.4857
#   Run 3/5 ...  eval loss = 0.4738
#   Run 4/5 ...  eval loss = 0.4793
#   Run 5/5 ...  eval loss = 0.4635
#
# === Depth 2, Width 2 ===
#   Run 1/5 ...  eval loss = 0.0018
#   Run 2/5 ...  eval loss = 0.4753
#   Run 3/5 ...  eval loss = 0.3483
#   Run 4/5 ...  eval loss = 0.0016
#   Run 5/5 ...  eval loss = 0.0008
#
# === Depth 2, Width 3 ===
#   Run 1/5 ...  eval loss = 0.0062
#   Run 2/5 ...  eval loss = 0.0005
#   Run 3/5 ...  eval loss = 0.0024
#   Run 4/5 ...  eval loss = 0.0015
#   Run 5/5 ...  eval loss = 0.0001
#
# === Depth 3, Width 1 ===
#   Run 1/5 ...  eval loss = 0.4911
#   Run 2/5 ...  eval loss = 0.4928
#   Run 3/5 ...  eval loss = 0.4733
#   Run 4/5 ...  eval loss = 0.4762
#   Run 5/5 ...  eval loss = 0.4800
#
# === Depth 3, Width 2 ===
#   Run 1/5 ...  eval loss = 0.0022
#   Run 2/5 ...  eval loss = 0.3373
#   Run 3/5 ...  eval loss = 0.4786
#   Run 4/5 ...  eval loss = 0.0009
#   Run 5/5 ...  eval loss = 0.3396
#
# === Depth 3, Width 3 ===
#   Run 1/5 ...  eval loss = 0.0006
#   Run 2/5 ...  eval loss = 0.0003
#   Run 3/5 ...  eval loss = 0.0043
#   Run 4/5 ...  eval loss = 0.0009
#   Run 5/5 ...  eval loss = 0.0022
#     depth  width  mean_eval_loss  std_eval_loss
# 0       0      1        0.694096       0.000953
# 1       0      2        0.693011       0.000646
# 2       0      3        0.693816       0.000574
# 3       1      1        0.487085       0.008841
# 4       1      2        0.208616       0.167031
# 5       1      3        0.070815       0.138357
# 6       2      1        0.475763       0.007299
# 7       2      2        0.165546       0.205024
# 8       2      3        0.002143       0.002187
# 9       3      1        0.482707       0.007897
# 10      3      2        0.231735       0.194775
# 11      3      3        0.001666       0.001479

# %% [markdown]
# ### Question 3.4

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

class MinimalXORNet(nn.Module):
    """
    Minimal XOR network:
    2 -> 2 (tanh) -> 1 (identity)
    """
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(2, 2, bias=True)   # hidden layer
        self.act = nn.Tanh()
        self.fc2 = nn.Linear(2, 1, bias=True)  # output layer (identity)
        
    def forward(self, x):
        h = self.act(self.fc1(x))
        out = self.fc2(h)  # logits
        return out
# Out:
# Using device: cpu

# %%
def plot_xor_boundaries(model, dataset, epoch=None, ax=None,
                        x_min=-0.5, x_max=1.5, n_points=300):
    """
    Plot training data + decision boundaries:
    - two hidden unit boundaries: a1(x)=0, a2(x)=0
    - output decision boundary: p(y=1|x)=0.5
    """
    model.eval()
    
    if ax is None:
        fig, ax = plt.subplots(figsize=(5, 5))
    
    # Scatter data
    X = dataset.x.numpy()
    y = dataset.y.numpy()
    class0 = X[y == 0]
    class1 = X[y == 1]
    ax.scatter(class0[:, 0], class0[:, 1], label="class 0", alpha=0.7, edgecolor="k")
    ax.scatter(class1[:, 0], class1[:, 1], label="class 1", alpha=0.7, edgecolor="k")
    
    # Grid for boundaries
    x1 = np.linspace(x_min, x_max, n_points)
    x2 = np.linspace(x_min, x_max, n_points)
    xx1, xx2 = np.meshgrid(x1, x2)
    grid = np.stack([xx1.ravel(), xx2.ravel()], axis=1)  # (N,2)
    
    with torch.no_grad():
        grid_t = torch.from_numpy(grid).float().to(device)
        
        # Hidden pre-activations: a = xW^T + b
        W1 = model.fc1.weight       # (2,2)
        b1 = model.fc1.bias         # (2,)
        a = grid_t @ W1.t() + b1    # (N,2)
        a = a.cpu().numpy()
        a1 = a[:, 0].reshape(xx1.shape)
        a2 = a[:, 1].reshape(xx1.shape)
        
        # Output probabilities
        logits = model(grid_t).squeeze(1)      # (N,)
        probs = torch.sigmoid(logits).cpu().numpy().reshape(xx1.shape)
    
    # Hidden unit boundaries: a1=0, a2=0
    cs1 = ax.contour(xx1, xx2, a1, levels=[0.0],
                    linestyles="--", linewidths=2)
    cs2 = ax.contour(xx1, xx2, a2, levels=[0.0],
                    linestyles="-.", linewidths=2)

    # Output decision boundary: p=0.5
    cs3 = ax.contour(xx1, xx2, probs, levels=[0.5],
                    colors="k", linewidths=2)

    # Labels for legend (only if contours exist)
    if cs1.collections:
        cs1.collections[0].set_label("hidden 1 boundary")
    if cs2.collections:
        cs2.collections[0].set_label("hidden 2 boundary")
    if cs3.collections:
        cs3.collections[0].set_label("output boundary (p=0.5)")

    
    ax.set_xlabel("x1")
    ax.set_ylabel("x2")
    title = "Decision boundaries"
    if epoch is not None:
        title += f" (epoch {epoch})"
    ax.set_title(title)
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(x_min, x_max)
    ax.grid(True)
    
    return ax

# %%
# Reuse your NoisyXORDataset from earlier:
# class NoisyXORDataset(Dataset): ...

# Training data
train_dataset = NoisyXORDataset(n_samples=2000, s=0.1, seed=123)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

model_xor = MinimalXORNet().to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model_xor.parameters(), lr=1e-2)

n_epochs = 100
snapshot_every = 5   # save weights every 5 epochs

snapshots = []       # list of state_dicts
snapshot_epochs = [] # corresponding epochs

for epoch in range(1, n_epochs + 1):
    model_xor.train()
    running_loss = 0.0
    total = 0
    
    for x_batch, y_batch in train_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        
        optimizer.zero_grad()
        logits = model_xor(x_batch).squeeze(1)
        loss = criterion(logits, y_batch)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * x_batch.size(0)
        total += x_batch.size(0)
    
    epoch_loss = running_loss / total
    
    if epoch % 10 == 0 or epoch == 1:
        print(f"Epoch {epoch:3d}/{n_epochs} - train loss: {epoch_loss:.4f}")
    
    # Save snapshot
    if epoch % snapshot_every == 0 or epoch == 1:
        snapshots.append({k: v.cpu().clone() for k, v in model_xor.state_dict().items()})
        snapshot_epochs.append(epoch)
# Out:
# Epoch   1/100 - train loss: 0.6990
# Epoch  10/100 - train loss: 0.1916
# Epoch  20/100 - train loss: 0.0480
# Epoch  30/100 - train loss: 0.0233
# Epoch  40/100 - train loss: 0.0142
# Epoch  50/100 - train loss: 0.0096
# Epoch  60/100 - train loss: 0.0071
# Epoch  70/100 - train loss: 0.0054
# Epoch  80/100 - train loss: 0.0043
# Epoch  90/100 - train loss: 0.0035
# Epoch 100/100 - train loss: 0.0029

# %%
from matplotlib.animation import PillowWriter
from IPython.display import Image, display

# Make sure snapshots are available before creating animation
if not snapshots:
    print("No snapshots available to create animation. Run the training cell that populates `snapshots` first.")
else:
    fig, ax = plt.subplots(figsize=(5, 5))

    def init():
        ax.clear()
        # load first snapshot (safe because we checked snapshots is not empty)
        model_xor.load_state_dict(snapshots[0])
        plot_xor_boundaries(model_xor, train_dataset, epoch=snapshot_epochs[0], ax=ax)
        return (ax,)

    def update(frame):
        ax.clear()
        idx = int(frame)
        # safety guards in case frame values are unexpected
        if idx < 0:
            idx = 0
        if idx >= len(snapshots):
            idx = len(snapshots) - 1
        model_xor.load_state_dict(snapshots[idx])
        plot_xor_boundaries(model_xor, train_dataset, epoch=snapshot_epochs[idx], ax=ax)
        return (ax,)

    anim = animation.FuncAnimation(
        fig,
        update,
        init_func=init,
        frames=range(len(snapshots)),
        interval=200,   # milliseconds between frames
        blit=False
    )

    # Save as GIF (catch errors to avoid crashing the notebook)
    try:
        anim.save("xor_decision_evolution.gif", writer=PillowWriter(fps=3))
        plt.close(fig)
        display(Image(filename="xor_decision_evolution.gif"))
    except Exception as e:
        plt.close(fig)
        print("Failed to save animation:", e)
# Out:
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:53: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   if cs1.collections:
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:54: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   cs1.collections[0].set_label("hidden 1 boundary")
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:55: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   if cs2.collections:
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:56: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   cs2.collections[0].set_label("hidden 2 boundary")
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:57: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   if cs3.collections:
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:58: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   cs3.collections[0].set_label("output boundary (p=0.5)")

# %%
# Choose 3–4 snapshots to include in the report
selected_indices = [0, len(snapshots)//10, 2*len(snapshots)//3, len(snapshots)-1]

for idx in selected_indices:
    epoch = snapshot_epochs[idx]
    model_xor.load_state_dict(snapshots[idx])
    
    fig, ax = plt.subplots(figsize=(5, 5))
    plot_xor_boundaries(model_xor, train_dataset, epoch=epoch, ax=ax)
    fig.tight_layout()
    fig.savefig(f"xor_boundaries_epoch_{epoch}.png", dpi=150)
# Out:
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:53: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   if cs1.collections:
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:54: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   cs1.collections[0].set_label("hidden 1 boundary")
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:55: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   if cs2.collections:
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:56: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   cs2.collections[0].set_label("hidden 2 boundary")
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:57: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   if cs3.collections:
# /var/folders/ck/_b2fnrn152vbbcxt5jf9gfth0000gn/T/ipykernel_71548/3018433403.py:58: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   cs3.collections[0].set_label("output boundary (p=0.5)")

# %% [markdown]
# ### Question 4.2

# %%
sweep_config = {
    "method": "random",   
    "metric": {
        "name": "val_loss",
        "goal": "minimize",
    },
    "parameters": {
        "learning_rate": {
            "values": [1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2, 1e-1, 3e-1],
        },
        "batch_size": {
            "values": [16, 32, 64, 128],
        },
        "width": {
            "values": [2, 3, 4, 5, 6],
        },
    },
}

# %%
def train_sweep():
    """
    Training function used by W&B agent for the sweep.
    Uses the same NoisyXORDataset and train_model() as in Exercise 3.1,
    but reads hyperparameters from wandb.config.
    """
    # start a new run; config is filled from sweep_config
    wandb.init(project="dl-assignment1-xor")
    config = wandb.config

    # data
    n_train = 2000
    n_val = 1000
    s = 0.1

    train_dataset = NoisyXORDataset(n_samples=n_train, s=s, seed=seed)
    val_dataset   = NoisyXORDataset(n_samples=n_val,   s=s, seed=seed + 1)

    train_loader = DataLoader(train_dataset,
                              batch_size=config.batch_size,
                              shuffle=True)
    val_loader   = DataLoader(val_dataset,
                              batch_size=config.batch_size,
                              shuffle=False)

    # model: depth fixed to 3, width from sweep
    depth = 3
    hidden_sizes = (config.width,) * depth
    model = FeedForwardNet(input_dim=2,
                           hidden_sizes=hidden_sizes,
                           output_dim=1).to(device)

    # loss + optimizer, lr from sweep
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(),
                                 lr=config.learning_rate)

    wandb.watch(model, log="all", log_freq=10)

    n_epochs = 100
    # train_model already calls wandb.log() each epoch
    _ = train_model(model, train_loader, val_loader,
                    criterion, optimizer, n_epochs=n_epochs)

    wandb.finish()

# %%
# Create the sweep on W&B and start an agent to run it
sweep_id = wandb.sweep(sweep=sweep_config,
                       project="dl-assignment1-xor")

# count controls how many runs you do (keep this modest)
wandb.agent(sweep_id, function=train_sweep, count=10)
# Out:
# Create sweep with ID: ayyojpb3
# Sweep URL: https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3
# wandb: Agent Starting Run: itslfenc with config:
# wandb: 	batch_size: 16
# wandb: 	learning_rate: 0.001
# wandb: 	width: 6
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184415-itslfenc</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/itslfenc' target="_blank">lunar-sweep-1</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/itslfenc' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/itslfenc</a>
# Epoch   1/100 | Train loss: 0.6916, acc: 0.532 | Val loss: 0.6897, acc: 0.497
# Epoch  10/100 | Train loss: 0.0167, acc: 1.000 | Val loss: 0.0149, acc: 1.000
# Epoch  20/100 | Train loss: 0.0026, acc: 1.000 | Val loss: 0.0026, acc: 1.000
# Epoch  30/100 | Train loss: 0.0009, acc: 1.000 | Val loss: 0.0010, acc: 1.000
# Epoch  40/100 | Train loss: 0.0004, acc: 1.000 | Val loss: 0.0004, acc: 1.000
# Epoch  50/100 | Train loss: 0.0002, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# Epoch  60/100 | Train loss: 0.0001, acc: 1.000 | Val loss: 0.0001, acc: 1.000
# Epoch  70/100 | Train loss: 0.0001, acc: 1.000 | Val loss: 0.0001, acc: 1.000
# Epoch  80/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  90/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch 100/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▆▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁██████████████████████████████████████</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>1e-05</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>1e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lunar-sweep-1</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/itslfenc' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/itslfenc</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184415-itslfenc/logs</code>
# wandb: Agent Starting Run: vvjl10pz with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.01
# wandb: 	width: 2
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184437-vvjl10pz</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/vvjl10pz' target="_blank">atomic-sweep-2</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/vvjl10pz' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/vvjl10pz</a>
# Epoch   1/100 | Train loss: 0.6720, acc: 0.567 | Val loss: 0.5976, acc: 0.757
# Epoch  10/100 | Train loss: 0.0059, acc: 1.000 | Val loss: 0.0053, acc: 1.000
# Epoch  20/100 | Train loss: 0.0015, acc: 1.000 | Val loss: 0.0014, acc: 1.000
# Epoch  30/100 | Train loss: 0.0007, acc: 1.000 | Val loss: 0.0007, acc: 1.000
# Epoch  40/100 | Train loss: 0.0004, acc: 1.000 | Val loss: 0.0004, acc: 1.000
# Epoch  50/100 | Train loss: 0.0002, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# Epoch  60/100 | Train loss: 0.0002, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# Epoch  70/100 | Train loss: 0.0001, acc: 1.000 | Val loss: 0.0001, acc: 1.000
# Epoch  80/100 | Train loss: 0.0001, acc: 1.000 | Val loss: 0.0001, acc: 1.000
# Epoch  90/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0001, acc: 1.000
# Epoch 100/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>4e-05</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>4e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">atomic-sweep-2</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/vvjl10pz' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/vvjl10pz</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184437-vvjl10pz/logs</code>
# wandb: Agent Starting Run: 5lwwft77 with config:
# wandb: 	batch_size: 64
# wandb: 	learning_rate: 0.3
# wandb: 	width: 2
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184453-5lwwft77</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/5lwwft77' target="_blank">electric-sweep-3</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/5lwwft77' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/5lwwft77</a>
# Epoch   1/100 | Train loss: 0.5659, acc: 0.697 | Val loss: 0.4860, acc: 0.743
# Epoch  10/100 | Train loss: 0.4825, acc: 0.752 | Val loss: 0.4842, acc: 0.743
# Epoch  20/100 | Train loss: 0.4807, acc: 0.752 | Val loss: 0.4841, acc: 0.743
# Epoch  30/100 | Train loss: 0.4820, acc: 0.752 | Val loss: 0.4900, acc: 0.743
# Epoch  40/100 | Train loss: 0.4966, acc: 0.728 | Val loss: 0.4955, acc: 0.743
# Epoch  50/100 | Train loss: 0.4832, acc: 0.752 | Val loss: 0.4887, acc: 0.743
# Epoch  60/100 | Train loss: 0.4874, acc: 0.752 | Val loss: 0.4987, acc: 0.743
# Epoch  70/100 | Train loss: 0.4879, acc: 0.752 | Val loss: 0.4896, acc: 0.743
# Epoch  80/100 | Train loss: 0.4894, acc: 0.735 | Val loss: 0.4935, acc: 0.743
# Epoch  90/100 | Train loss: 0.4830, acc: 0.752 | Val loss: 0.4946, acc: 0.743
# Epoch 100/100 | Train loss: 0.5108, acc: 0.714 | Val loss: 0.4991, acc: 0.743
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁█████████████████████████████▆████████▃</td></tr><tr><td>train_loss</td><td>█▂▁▁▂▁▁▁▂▁▁▂▂▁▁▁▁▁▁▁▂▂▂▁▁▁▂▂▃▂▁▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▂▅█▂▁▂▁▁▁▃▃▇▂▂▂▂▃▂▁▃▁▁▁▁▂▅▁▂▂▃▂▂▆▁▁▂▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>0.7135</td></tr><tr><td>train_loss</td><td>0.51079</td></tr><tr><td>val_acc</td><td>0.743</td></tr><tr><td>val_loss</td><td>0.49908</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">electric-sweep-3</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/5lwwft77' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/5lwwft77</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184453-5lwwft77/logs</code>
# wandb: Agent Starting Run: 6fb2i9uf with config:
# wandb: 	batch_size: 128
# wandb: 	learning_rate: 0.0003
# wandb: 	width: 5
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184504-6fb2i9uf</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/6fb2i9uf' target="_blank">upbeat-sweep-4</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/6fb2i9uf' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/6fb2i9uf</a>
# Epoch   1/100 | Train loss: 0.7024, acc: 0.491 | Val loss: 0.7018, acc: 0.503
# Epoch  10/100 | Train loss: 0.6945, acc: 0.747 | Val loss: 0.6952, acc: 0.740
# Epoch  20/100 | Train loss: 0.6873, acc: 0.698 | Val loss: 0.6885, acc: 0.692
# Epoch  30/100 | Train loss: 0.6734, acc: 0.729 | Val loss: 0.6748, acc: 0.722
# Epoch  40/100 | Train loss: 0.6479, acc: 0.745 | Val loss: 0.6502, acc: 0.738
# Epoch  50/100 | Train loss: 0.6135, acc: 0.747 | Val loss: 0.6170, acc: 0.740
# Epoch  60/100 | Train loss: 0.5728, acc: 0.749 | Val loss: 0.5765, acc: 0.742
# Epoch  70/100 | Train loss: 0.5148, acc: 0.749 | Val loss: 0.5164, acc: 0.744
# Epoch  80/100 | Train loss: 0.4294, acc: 0.878 | Val loss: 0.4264, acc: 0.904
# Epoch  90/100 | Train loss: 0.3257, acc: 0.992 | Val loss: 0.3195, acc: 0.995
# Epoch 100/100 | Train loss: 0.2371, acc: 1.000 | Val loss: 0.2304, acc: 0.998
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▄▄▄▅▄▄▄▄▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▅▆▆▇██████████</td></tr><tr><td>train_loss</td><td>██████████████▇▇▇▇▇▇▇▆▆▆▆▆▅▅▅▄▄▃▃▃▃▂▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▅▆▇███████</td></tr><tr><td>val_loss</td><td>███████████████▇▇▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>0.9995</td></tr><tr><td>train_loss</td><td>0.23705</td></tr><tr><td>val_acc</td><td>0.998</td></tr><tr><td>val_loss</td><td>0.23043</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">upbeat-sweep-4</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/6fb2i9uf' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/6fb2i9uf</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184504-6fb2i9uf/logs</code>
# wandb: Agent Starting Run: kgaxpqi6 with config:
# wandb: 	batch_size: 128
# wandb: 	learning_rate: 0.0003
# wandb: 	width: 6
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184514-kgaxpqi6</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/kgaxpqi6' target="_blank">youthful-sweep-5</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/kgaxpqi6' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/kgaxpqi6</a>
# Epoch   1/100 | Train loss: 0.6961, acc: 0.491 | Val loss: 0.6939, acc: 0.503
# Epoch  10/100 | Train loss: 0.6874, acc: 0.719 | Val loss: 0.6880, acc: 0.705
# Epoch  20/100 | Train loss: 0.6769, acc: 0.646 | Val loss: 0.6786, acc: 0.630
# Epoch  30/100 | Train loss: 0.6566, acc: 0.685 | Val loss: 0.6593, acc: 0.662
# Epoch  40/100 | Train loss: 0.6182, acc: 0.722 | Val loss: 0.6215, acc: 0.707
# Epoch  50/100 | Train loss: 0.5500, acc: 0.744 | Val loss: 0.5517, acc: 0.738
# Epoch  60/100 | Train loss: 0.4364, acc: 0.998 | Val loss: 0.4340, acc: 0.999
# Epoch  70/100 | Train loss: 0.3006, acc: 1.000 | Val loss: 0.2960, acc: 1.000
# Epoch  80/100 | Train loss: 0.1914, acc: 1.000 | Val loss: 0.1874, acc: 1.000
# Epoch  90/100 | Train loss: 0.1221, acc: 1.000 | Val loss: 0.1193, acc: 1.000
# Epoch 100/100 | Train loss: 0.0815, acc: 1.000 | Val loss: 0.0796, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇███</td></tr><tr><td>train_acc</td><td>▁▁▃▄▄▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▇███████████████████</td></tr><tr><td>train_loss</td><td>███████████▇▇▇▇▆▆▆▆▆▅▄▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▄▄▄▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▇███████████████</td></tr><tr><td>val_loss</td><td>█████████████▇▇▇▇▇▆▆▆▅▅▅▄▃▃▃▃▃▃▂▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.08151</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>0.07959</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">youthful-sweep-5</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/kgaxpqi6' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/kgaxpqi6</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184514-kgaxpqi6/logs</code>
# wandb: Agent Starting Run: mvevt4jb with config:
# wandb: 	batch_size: 16
# wandb: 	learning_rate: 0.01
# wandb: 	width: 6
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184525-mvevt4jb</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/mvevt4jb' target="_blank">cerulean-sweep-6</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/mvevt4jb' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/mvevt4jb</a>
# Epoch   1/100 | Train loss: 0.4764, acc: 0.745 | Val loss: 0.0146, acc: 1.000
# Epoch  10/100 | Train loss: 0.0003, acc: 1.000 | Val loss: 0.0003, acc: 1.000
# Epoch  20/100 | Train loss: 0.0001, acc: 1.000 | Val loss: 0.0001, acc: 1.000
# Epoch  30/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  40/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  50/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  60/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  70/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  80/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  90/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch 100/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇█</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.0</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cerulean-sweep-6</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/mvevt4jb' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/mvevt4jb</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184525-mvevt4jb/logs</code>
# wandb: Agent Starting Run: 0vdnxfks with config:
# wandb: 	batch_size: 16
# wandb: 	learning_rate: 0.1
# wandb: 	width: 6
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184546-0vdnxfks</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0vdnxfks' target="_blank">sweet-sweep-7</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0vdnxfks' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0vdnxfks</a>
# Epoch   1/100 | Train loss: 0.1866, acc: 0.906 | Val loss: 0.0010, acc: 1.000
# Epoch  10/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  20/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  30/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  40/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  50/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  60/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  70/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  80/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  90/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch 100/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.0</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweet-sweep-7</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0vdnxfks' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0vdnxfks</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184546-0vdnxfks/logs</code>
# wandb: Agent Starting Run: o9fex7of with config:
# wandb: 	batch_size: 16
# wandb: 	learning_rate: 0.03
# wandb: 	width: 3
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184607-o9fex7of</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/o9fex7of' target="_blank">honest-sweep-8</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/o9fex7of' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/o9fex7of</a>
# Epoch   1/100 | Train loss: 0.6067, acc: 0.657 | Val loss: 0.4982, acc: 0.743
# Epoch  10/100 | Train loss: 0.0014, acc: 1.000 | Val loss: 0.0013, acc: 1.000
# Epoch  20/100 | Train loss: 0.0004, acc: 1.000 | Val loss: 0.0004, acc: 1.000
# Epoch  30/100 | Train loss: 0.0001, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# Epoch  40/100 | Train loss: 0.0001, acc: 1.000 | Val loss: 0.0001, acc: 1.000
# Epoch  50/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  60/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  70/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  80/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  90/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch 100/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.0</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">honest-sweep-8</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/o9fex7of' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/o9fex7of</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184607-o9fex7of/logs</code>
# wandb: Agent Starting Run: 0prlsrs1 with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.1
# wandb: 	width: 3
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184629-0prlsrs1</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0prlsrs1' target="_blank">summer-sweep-9</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0prlsrs1' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0prlsrs1</a>
# Epoch   1/100 | Train loss: 0.2951, acc: 0.851 | Val loss: 0.0035, acc: 1.000
# Epoch  10/100 | Train loss: 0.0002, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# Epoch  20/100 | Train loss: 0.0001, acc: 1.000 | Val loss: 0.0001, acc: 1.000
# Epoch  30/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  40/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  50/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  60/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  70/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  80/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch  90/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# Epoch 100/100 | Train loss: 0.0000, acc: 1.000 | Val loss: 0.0000, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.0</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>0.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">summer-sweep-9</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0prlsrs1' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/0prlsrs1</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184629-0prlsrs1/logs</code>
# wandb: Agent Starting Run: sp4zvrfz with config:
# wandb: 	batch_size: 64
# wandb: 	learning_rate: 0.01
# wandb: 	width: 6
# Ignoring project 'dl-assignment1-xor' when running a sweep.
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/Users/lassestrandbygaard/Downloads/wandb/run-20251128_184651-sp4zvrfz</code>
# Syncing run <strong><a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/sp4zvrfz' target="_blank">stellar-sweep-10</a></strong> to <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View project at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a>
#  View sweep at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/sweeps/ayyojpb3</a>
#  View run at <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/sp4zvrfz' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/sp4zvrfz</a>
# Epoch   1/100 | Train loss: 0.6758, acc: 0.645 | Val loss: 0.6023, acc: 0.743
# Epoch  10/100 | Train loss: 0.0109, acc: 1.000 | Val loss: 0.0102, acc: 1.000
# Epoch  20/100 | Train loss: 0.0034, acc: 1.000 | Val loss: 0.0034, acc: 1.000
# Epoch  30/100 | Train loss: 0.0017, acc: 1.000 | Val loss: 0.0018, acc: 1.000
# Epoch  40/100 | Train loss: 0.0011, acc: 1.000 | Val loss: 0.0011, acc: 1.000
# Epoch  50/100 | Train loss: 0.0007, acc: 1.000 | Val loss: 0.0007, acc: 1.000
# Epoch  60/100 | Train loss: 0.0005, acc: 1.000 | Val loss: 0.0005, acc: 1.000
# Epoch  70/100 | Train loss: 0.0004, acc: 1.000 | Val loss: 0.0004, acc: 1.000
# Epoch  80/100 | Train loss: 0.0003, acc: 1.000 | Val loss: 0.0003, acc: 1.000
# Epoch  90/100 | Train loss: 0.0002, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# Epoch 100/100 | Train loss: 0.0002, acc: 1.000 | Val loss: 0.0002, acc: 1.000
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▃██████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▆▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>train_acc</td><td>1</td></tr><tr><td>train_loss</td><td>0.00018</td></tr><tr><td>val_acc</td><td>1</td></tr><tr><td>val_loss</td><td>0.00019</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-sweep-10</strong> at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/sp4zvrfz' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor/runs/sp4zvrfz</a><br> View project at: <a href='https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor' target="_blank">https://wandb.ai/last24ag-copenhagen-business-school/dl-assignment1-xor</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251128_184651-sp4zvrfz/logs</code>
